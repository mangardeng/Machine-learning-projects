# %% [markdown]
# ## Implementation of Ada_Boost Algorithm

# %%
from IPython.display import Image
Image(filename='Ada Boost.PNG')

# %%
#importing neccessary packages
#load Libraries
import pandas as pd
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Preparation

# %%
#load data -loading iris data
loadData = pd.read_csv("Ada_boost_Income_datasets.csv")
loadData.head()
# Out:
#    age  fnlwgt  education_num  capital_gain  capital_loss  hours_per_week  \
# 0   39   77516             13          2174             0              40
# 1   50   83311             13             0             0              13
# 2   38  215646              9             0             0              40
# 3   53  234721              7             0             0              40
# 4   28  338409             13             0             0              40
#
#    income_level
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
#Separateing predictors and response
X = loadData.iloc[:,0:6]
y = loadData.iloc[:,6]

# %%
#split dataset into traing set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) # that is 75% tarining and 25% test

# %% [markdown]
# ## Model training and evaluation

# %%
#create adaboost classifier object
AdaModel = AdaBoostClassifier(n_estimators=100,
                              learning_rate=1)

# %%
#important parameters
#n_estimators:Number of weak learners to train iteratively.
#learning_rate: it contributes to the weights of weak learners. it uses 1 as a default value.

# %%
#Train Adaboost classifer
model = AdaModel.fit(X_train, y_train)

#predict the response for test dataset
y_pred = model.predict(X_test)

# %%
#model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8387757191114751

# %% [markdown]
# ## lets learn few more importance aspects of AdaBoost

# %%
#import logistic regression  sklearn, kinear_model import logisticRegression
from sklearn.linear_model import LogisticRegression
mylogregmodel = LogisticRegression()

#create adaboost clssifier object
adabc = AdaBoostClassifier(n_estimators=150, estimator=mylogregmodel, learning_rate=1)

#Train Adaboost Classifier
model = adabc.fit(X_train, y_train)

#predict the response for the test dataset
y_pred = model.predict(X_test)

#model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8055072167059064

# %% [markdown]
# ## Pros:
# Easy to implement.
# Iteratively corrects the mistakes of the weak classifier and improves accuracy by combining weak learners.
# we use many base classifiers with Adaboost.
# AdabBoost is not prone to overfitting.
# ## Cons:
#     AdaBoost is senitive to noise and outliers.
